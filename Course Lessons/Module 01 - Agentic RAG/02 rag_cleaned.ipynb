# %%
from rag_helper import RAGBase
from ingest import load_faq_data, build_index

# %%
from openai import OpenAI
import os

# uncomment below to use openai
# openai_client = OpenAI()

# uncomment below if using groq instead
openai_client = OpenAI(
    api_key=os.getenv("GROQ_API_KEY"),
    base_url="https://api.groq.com/openai/v1"
)

# %%
documents = load_faq_data()
index = build_index(documents)

assistant = RAGBase(index, openai_client, model='qwen/qwen3-32b')   # if using openai instead of groq, no need to pass model parameter

# %%
assistant.rag('I just discovered the course, can I still join?')
# Out:
# "Yes, you can still join the course at any time! Here's what to know based on the current policies:\n\n1. **Joining the Course**:  \n   - There is no enrollment deadline—start learning immediately using the [LLM Zoomcamp docs](https://datatalks.club/docs/courses/llm-zoomcamp/), [general logistics](https://datatalks.club/docs/courses/zoomcamp-logistics/), and [GitHub repository](https://github.com/DataTalksClub/llm-zoomcamp).  \n   - No confirmation email is required, and registration is optional (it’s only used to gauge interest prior to the start date).\n\n2. **Certificate Eligibility**:  \n   - To receive a certificate, you **must submit your Capstone project while the submission window is open** (before the course deadline).  \n   - Homework is optional and does not impact certificate eligibility, but it’s recommended for reinforcing concepts. Points from homework count toward your leaderboard ranking.  \n   - Certificates are **only awarded for live cohorts**, not self-paced completion. Peer reviews for the Capstone occur during the active course period, so you must submit your project and complete peer reviews within the deadline.\n\n3. **Missed Content**:  \n   If you’ve missed earlier lessons or homework, you can catch up by reviewing all available videos, notebooks, and homework instructions via the course materials. Deadlines for Capstone submissions are listed in the [course management platform](https://courses.datatalks.club/llm-zoomcamp-2026/).\n\n**Next Steps**:  \n- Begin with the LLM Zoomcamp docs and GitHub repo.  \n- Follow the typical workflow: watch videos ⟶ work through code/lessons ⟶ submit homework (optional) and complete the Capstone by the deadline (required for a certificate).  \n\nYou’re good to go—they don’t check registration against deadlines, so start learning and submit your work while the Capstone submissions are still open! 🚀"
