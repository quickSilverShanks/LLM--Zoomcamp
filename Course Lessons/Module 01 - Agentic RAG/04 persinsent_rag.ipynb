# %%
from sqlitesearch import TextSearchIndex

sqlite_index = TextSearchIndex(
    text_fields=['question', 'section', 'answer'],
    keyword_fields=['course'],
    db_path='faq.db'
)

# %%
from dotenv import load_dotenv
load_dotenv()

from openai import OpenAI
import os

# uncomment below to use openai
# openai_client = OpenAI()

# uncomment below if using groq instead
openai_client = OpenAI(
    api_key=os.getenv("GROQ_API_KEY"),
    base_url="https://api.groq.com/openai/v1"
)

# %%
from rag_helper import RAGBase

assistant = RAGBase(sqlite_index, openai_client, model='qwen/qwen3-32b')   # if using openai instead of groq, no need to pass model parameter

# %%
assistant.rag('I just discovered the course, can I still join?')
# Out:
# 'Yes, you can still join the course even if you just discovered it! Here are the key points to consider:  \n\n1. **Joining the Course**:  \n   - No confirmation email is required upon registration—registration is optional and primarily for gauging interest. You can start learning and submitting homework *immediately* while the submission form is open.  \n\n2. **Certificate Eligibility**:  \n   - To receive a certificate, you **must submit your project while submissions are still open**.  \n   - A certificate is **not awarded for self-paced learning only**. You must complete the course within a "live cohort" to participate in the required peer-review step for the Capstone project.  \n   - Missing homework does not disqualify you for the certificate, but **passing the Capstone project** is mandatory.  \n\n3. **Technical Notes**:  \n   - While the course provides a CodeSpaces environment, you can also run modules locally if preferred (setup is your responsibility). Ensure your environme
# ...

# %%
assistant.rag('Will we learn how to use langchain in llm zoomcamp?')
# Out:
# 'No, the **LLM Zoomcamp** does not include direct instruction on using **LangChain** in its curriculum. The course focuses on building core components of LLM applications from scratch, such as **prompting, retrieval, indexing, and evaluation**, without relying on frameworks like LangChain. \n\n### Key Points from the Context:\n1. **Why Not LangChain?**  \n   The course emphasizes learning foundational concepts (e.g., "HTML/CSS/JS of LLMs") before using frameworks like LangChain ("React/Angular"). This approach ensures students understand what frameworks automate, enabling them to use them more effectively in the future.\n\n2. **LangChain in the Curriculum?**  \n   There is no mention of LangChain being taught in the course. The focus remains on hands-on, low-level implementation to develop deep technical understanding.\n\n3. **Post-Course Implications**  \n   While the course itself does not teach LangChain, the skills gained (e.g., building retrieval systems, prompt engineering, and
# ...
